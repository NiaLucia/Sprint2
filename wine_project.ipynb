# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt 
import seaborn as sns

# %%
red_wine = pd.read_csv('Wine Project\winequality-red.csv', delimiter= ';')

white_wine = pd.read_csv('Wine Project\winequality-white.csv', delimiter= ';')

# %%
red_wines = pd.DataFrame(red_wine)
white_wines = pd.DataFrame(white_wine)

red_wines = round(red_wines, 2)
white_wines = round(white_wines, 2)

# %%
# Data Wrangling
# Head & Tail red wines

red_wines.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9       0.08
# 1            7.8              0.88         0.00             2.6       0.10
# 2            7.8              0.76         0.04             2.3       0.09
# 3           11.2              0.28         0.56             1.9       0.08
# 4            7.4              0.70         0.00             1.9       0.08
# 5            7.4              0.66         0.00             1.8       0.08
# 6            7.9              0.60         0.06             1.6       0.07
# 7            7.3              0.65         0.00             1.2       0.06
# 8            7.8              0.58         0.02             2.0       0.07
# 9            7.5              0.50         0.36             6.1       0.07
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
red_wines.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6              0.72         0.20             7.8       0.07
# 1590            6.3              0.55         0.15             1.8       0.08
# 1591            5.4              0.74         0.09             1.7       0.09
# 1592            6.3              0.51         0.13             2.3       0.08
# 1593            6.8              0.62         0.08             1.9       0.07
# 1594            6.2              0.60         0.08             2.0       0.09
# 1595            5.9              0.55         0.10             2.2       0.06
# 1596            6.3              0.51         0.13             2.3       0.08
# 1597            5.9              0.64         0.12             2.0       0.08
# 1598            6.0              0.31         0.47             3.6       0.07
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
# head and tail white wines

white_wines.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7       0.04
# 1            6.3              0.30         0.34             1.6       0.05
# 2            8.1              0.28         0.40             6.9       0.05
# 3            7.2              0.23         0.32             8.5       0.06
# 4            7.2              0.23         0.32             8.5       0.06
# 5            8.1              0.28         0.40             6.9       0.05
# 6            6.2              0.32         0.16             7.0       0.04
# 7            7.0              0.27         0.36            20.7       0.04
# 8            6.3              0.30         0.34             1.6       0.05
# 9            8.1              0.22         0.43             1.5       0.04
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
white_wines.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8              0.22         0.36            1.20       0.05
# 4889            4.9              0.24         0.27           11.75       0.03
# 4890            6.1              0.34         0.29            2.20       0.04
# 4891            5.7              0.21         0.32            0.90       0.04
# 4892            6.5              0.23         0.38            1.30       0.03
# 4893            6.2              0.21         0.29            1.60       0.04
# 4894            6.6              0.32         0.36            8.00       0.05
# 4895            6.5              0.24         0.19            1.20       0.04
# 4896            5.5              0.29         0.30            1.10       0.02
# 4897            6.0              0.21         0.38            0.80       0.02
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
# shape red wine

red_wines.shape
# Out:
# (1599, 12)

# %%
# shape white wine

white_wines.shape
# Out:
# (4898, 12)

# %%
# info red wine

red_wines.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9       0.08
# 1               7.8              0.88         0.00             2.6       0.10
# 2               7.8              0.76         0.04             2.3       0.09
# 3              11.2              0.28         0.56             1.9       0.08
# 4               7.4              0.70         0.00             1.9       0.08
# ...             ...               ...          ...             ...        ...
# 1594            6.2              0.60         0.08             2.0       0.09
# 1595            5.9              0.55         0.10             2.2       0.06
# 1596            6.3              0.51         0.13             2.3       0.08
# 1597            5.9              0.64         0.12             2.0       0.08
# 1598            6.0              0.31         0.47             3.6       0.07
#
# ...

# %%
# info white wine

white_wines.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7       0.04
# 1               6.3              0.30         0.34             1.6       0.05
# 2               8.1              0.28         0.40             6.9       0.05
# 3               7.2              0.23         0.32             8.5       0.06
# 4               7.2              0.23         0.32             8.5       0.06
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6       0.04
# 4894            6.6              0.32         0.36             8.0       0.05
# 4895            6.5              0.24         0.19             1.2       0.04
# 4896            5.5              0.29         0.30             1.1       0.02
# 4897            6.0              0.21         0.38             0.8       0.02
#
# ...

# %%
# isna red

red_wines.isna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
# isna white

white_wines.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# describe red 

red_wines.describe().round(2)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        1599.00           1599.00      1599.00         1599.00
# mean            8.32              0.53         0.27            2.54
# std             1.74              0.18         0.19            1.41
# min             4.60              0.12         0.00            0.90
# 25%             7.10              0.39         0.09            1.90
# 50%             7.90              0.52         0.26            2.20
# 75%             9.20              0.64         0.42            2.60
# max            15.90              1.58         1.00           15.50
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density       pH  \
# count    1599.00              1599.00               1599.00  1599.00  1599.00
# mean        0.09                15.87                 46.47     1.00     3.31
# std         0.05                10.46                 32.90     0.00     0.15
# ...

# %%
# describe white

white_wines.describe().round(2)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        4898.00           4898.00      4898.00         4898.00
# mean            6.85              0.28         0.33            6.39
# std             0.84              0.10         0.12            5.07
# min             3.80              0.08         0.00            0.60
# 25%             6.30              0.21         0.27            1.70
# 50%             6.80              0.26         0.32            5.20
# 75%             7.30              0.32         0.39            9.90
# max            14.20              1.10         1.66           65.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density       pH  \
# count    4898.00              4898.00               4898.00  4898.00  4898.00
# mean        0.05                35.31                138.36     0.99     3.19
# std         0.02                17.01                 42.50     0.00     0.15
# ...

# %%
# Let's now group our qualities into 3 categories: low, medium and high quality wines.
# we are creating a new column called "quality_label", we define a range and associate that range with a label


red_wines['quality_label'] = red_wines['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# %%
# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string

red_wines['quality_label'] = pd.Categorical(red_wines['quality_label'],
categories=['low', 'medium', 'high'])

# %%
white_wines['quality_label'] = white_wines['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

white_wines['quality_label'] = pd.Categorical(white_wines['quality_label'],
categories=['low', 'medium', 'high'])

# %%
# Epic 3: Exploratory Analysis

pd.concat([red_wines.describe().round(2), white_wines.describe().round(2)], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                                        \
#         fixed acidity volatile acidity citric acid residual sugar chlorides
# count         1599.00          1599.00     1599.00        1599.00   1599.00
# mean             8.32             0.53        0.27           2.54      0.09
# std              1.74             0.18        0.19           1.41      0.05
# min              4.60             0.12        0.00           0.90      0.01
# 25%              7.10             0.39        0.09           1.90      0.07
# 50%              7.90             0.52        0.26           2.20      0.08
# 75%              9.20             0.64        0.42           2.60      0.09
# max             15.90             1.58        1.00          15.50      0.61
#
#                                                                             \
#       free sulfur dioxide total sulfur dioxide  density       pH sulphates
# ...

# %%
# comments:
# the mean residual sugar in red wine is 2.54 and in white 6.39 --> more sugar means more ripened or warm climate
# the mean of total sulfur dioxide in red is 46.47 and in white 138.36
# red wine has more sulphates (0.66) than white (0.49)
# the volatile acidity of red is higher (0.53) than white (0.28)

# %%
# pie chart quantity red and white wines

data = [red_wines, white_wines]
keys = ['Red Wine', 'White Wine']

plt.pie(red_wines["quality"].value_counts())
plt.show()

# %%
# Seaborn Histplot

sns.histplot(data=red_wines, x= 'quality_label', bins=10, color= 'salmon').set_title('Quality Label Red Wines')
# Out:
# Text(0.5, 1.0, 'Quality Label Red Wines')

# %%
sns.histplot(data=white_wines, x= "quality_label", bins=10, color= 'beige').set_title('Quality Label White Wines')
# Out:
# Text(0.5, 1.0, 'Quality Label White Wines')

# %%
# boxplot ALCOHOL & QUALITY RED WINE

sns.boxplot(data=red_wines, x= "quality_label", y= "alcohol", palette= "rocket").set_title('Alcohol & Quality Red Wines')
# Out:
# Text(0.5, 1.0, 'Alcohol & Quality Red Wines')

# %%
fig, axs = plt.subplots(1, 2, sharey="row", tight_layout=True) # sharey = "row" makes the y-axis similar.

# axs[0].set_title("Budget")
# axs[1].set_title("Gross")

# axs[0].boxplot(data=red_wines["quality_label"], x='alcohol', palette= "rocket") 
# axs[1].boxplot(data=red_wines["quality_label"], x='alcohol', palette= "rocket")

sns.boxplot(ax = axs[0], data=red_wines, x="quality_label", y="alcohol")
# Out:
# <AxesSubplot:xlabel='quality_label', ylabel='alcohol'>

# %%
# boxplot pH & QUALITY RED WINE

sns.boxplot(data=red_wines, x= "quality_label", y= "pH", palette= "rocket").set_title('pH & Quality Red Wines')
# Out:
# Text(0.5, 1.0, 'pH & Quality Red Wines')

# %%
# boxplot ALCOHOL & QUALITY WHITE WINE

sns.boxplot(data=white_wines, x= "quality_label", y= "alcohol", color= "beige").set_title('Alcohol & Quality White Wines')
# Out:
# Text(0.5, 1.0, 'Alcohol & Quality White Wines')

# %%
# boxplot pH & QUALITY WHITE WINE

sns.boxplot(data=white_wines, x= "quality_label", y= "pH", color= "beige").set_title('pH & Quality White Wines')
# Out:
# Text(0.5, 1.0, 'pH & Quality White Wines')

# %%
sns.boxplot(data=red_wines, x= "quality_label", y= "pH", color= "salmon").set_title('pH & Quality Red Wines')
# Out:
# Text(0.5, 1.0, 'pH & Quality Red Wines')

# %%
# investigated whether wine’s pH and sulfur content could be used to accurately predict its quality

sns.histplot(data=red_wines, x= 'quality_label', bins=10, color= 'salmon').set_title('Quality Label Red Wines')

sns.barplot(data=red_wines, x="pH", y="body_mass_g", hue="sex")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24208\4174792735.py in <module>
#       3 sns.histplot(data=red_wines, x= 'quality_label', bins=10, color= 'salmon').set_title('Quality Label Red Wines')
#       4
# ----> 5 sns.barplot(data=red_wines, x="pH", y="body_mass_g", hue="sex")
#
# c:\Users\Lucia\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\Users\Lucia\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# ...

# %%
# The FSO2 and the pH of your wine determine how much SO2 is available in the active, 
# molecular form to help protect the wine from oxidation and spoilage. 

sns.histplot(data=red_wines, x="total sulfur dioxide", y="pH", bins=20)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='pH'>

# %%
sns.catplot(
    data=red_wines, kind="strip",
    x="pH", y="quality_label")

# %%
# WHY WHITE WINE HAS MORE total sulfur dioxide - more prone to oxidation
# White wines and Rosé wines don’t tend to contain natural anti-oxidants because they do not tend to be left in contact with their skins after crushing. For this reason, they are more prone to oxidation and tend to be given larger doses of sulphur dioxide.

fig, axs = plt.subplots(1, 2, sharey="row", tight_layout=True) 

sns.boxplot(ax = axs[0], data=red_wines, x="quality_label", y="total sulfur dioxide", color='salmon').set_title('Red Wine')
sns.boxplot(ax = axs[1], data=white_wines, x="quality_label", y="total sulfur dioxide", color='beige').set_title('White Wine')
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
fig, axs = plt.subplots(1, 2, sharey="row", tight_layout=True) 

sns.boxplot(ax = axs[0], data=red_wines, x="quality_label", y="total sulfur dioxide", color='salmon').set_title('Red Wine')
sns.boxplot(ax = axs[1], data=white_wines, x="quality_label", y="total sulfur dioxide", color='beige').set_title('White Wine')
# Out:
# Text(0.5, 1.0, 'White Wine')

# %%
sns.catplot(data=white_wines, x="residual sugar", y="quality_label", kind='box', color= 'beige')

# %%
# residual sugar in wines & quality

sns.boxplot(data=red_wines, x= 'residual sugar', y= 'quality_label')
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality_label'>

# %%
fig, axs = plt.subplots(1, 2, sharey="row", tight_layout=True) 

sns.histplot(ax = axs[0], data=red_wines, x="chlorides", color='salmon', bins=30).set_title('Red Wine Chlorides')
sns.histplot(ax = axs[1], data=white_wines, x="chlorides", color='beige', bins=30).set_title('White Wine Chlorides')
# Out:
# Text(0.5, 1.0, 'White Wine Chlorides')

# %%
plt.subplots (2, figsize=(25, 15), tight_layout=True)
sns.histplot(x='alcohol', y='chlorides', data=white_wines, ax=axs[1])
sns.histplot(x='alcohol', y='chlorides', data=red_wines, ax=axs[0])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='chlorides'>

# %%
sns.scatterplot(data=red_wines, x="total sulfur dioxide", y="pH", hue='quality_label')
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='pH'>

# %%
fig, axs = plt.subplots(1, 2, sharey="row", tight_layout=True) 

sns.boxplot(ax = axs[0], data=red_wines, x="quality_label", y="total sulfur dioxide", color='salmon').set_title('Red Wine')
sns.boxplot(ax = axs[1], data=white_wines, x="quality_label", y="total sulfur dioxide", color='beige').set_title('White Wine')

# %%
sns.catplot(x='citric acid', data=white_wines, kind='violin', col='quality_label' ,color='beige')

# %%
sns.displot(data='red_wines')   #hulahoop

# %%
# Chart 1

sns.histplot(data='red_wines')
